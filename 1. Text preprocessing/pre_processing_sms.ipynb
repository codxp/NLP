# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import pandas as pd
import string
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# # SUB FUNCTION TO PRE-PROCESS STRING:

# %%
# Lowercasing:

def text_lower_case(text):

  return text.lower()


# Removing numbers/digits:

def remove_numbers(text):

  result = re.sub("\d+", "", text)

  return result


# Removing ponctuation & special characters:

def remove_punctuation(text):

  regular_punct = list(string.punctuation)

  for punct in regular_punct:

    if punct in text:

      text = text.replace(punct, "")

  return text.strip()


# Handling double whitespace:

def remove_whitespace(text):

  return " ".join(text.split())


# Define a function to remove URLs from text:

def remove_url(text):

  url_patterns = []
  url_patterns.append(re.compile(r'https?://\S+'))
  url_patterns.append(re.compile(r'http?://\S+'))
  url_patterns.append(re.compile(r'www\.\S+'))

  for pattern in url_patterns:
    pattern.sub("", text)

  return text


# Define a function to remove stop-words from a list of words:

def remove_stopwords(words_list):

  stop_words = set(stopwords.words('english'))

  # Filter out the stopwords:
  filtered_text = [word for word in words_list if word.lower() not in stop_words]

  return filtered_text


# Stemming

def stem_word(text):
  word_tokens = word_tokenize(text)
  stems = [stemmer.stem(word) for word in word_tokens]

  return stems


# Lemmatization:

def lemma_words(text):

  word_tokens = word_tokenize(text)
  lemmas = [lemmatizer.lemmatize(word) for word in word_tokens]

  return lemmas

# %% [markdown]
# # FUNCTION WHO APPLY ALL SUB-FUNCTION FROM DATAFRAME:

# %%
# Function to pre-process dataframe (.csv) with case normalization, noise removal, tokenization, stop-word, stemming and lemmatization:

def pre_processing(path_file_csv, encoding):

  df = pd.read_csv(path_file_csv, encoding=encoding)

  for index, row in df.iterrows():

    text_lower = row['Message_body'].lower()
    df.loc[index, 'Case Normalization'] = text_lower

    noise_remove_text = remove_numbers(text_lower)
    noise_remove_text = remove_punctuation(noise_remove_text)
    noise_remove_text = remove_whitespace(noise_remove_text)
    noise_remove_text = remove_url(noise_remove_text)
    df.loc[index, 'Noise Removal'] = noise_remove_text

    tokenized = nltk.wordpunct_tokenize(noise_remove_text)
    df.loc[index, 'Tokenization'] = str(tokenized)

    stop_word = remove_stopwords(tokenized)
    df.loc[index, 'Stopwords'] = str(stop_word)

    stem = stem_word(noise_remove_text)
    df.loc[index, 'Stemming'] = str(stem)

    lemma = lemma_words(noise_remove_text)
    df.loc[index, 'Lemmatization'] = str(lemma)

  return df

# %%
pre_processing('/content/drive/MyDrive/Colab Notebooks/SMS_test.csv', 'latin')
# Out:
#      S. No.                                       Message_body     Label  \
# 0         1  UpgrdCentre Orange customer, you may now claim...      Spam
# 1         2  Loan for any purpose £500 - £75,000. Homeowner...      Spam
# 2         3  Congrats! Nokia 3650 video camera phone is you...      Spam
# 3         4  URGENT! Your Mobile number has been awarded wi...      Spam
# 4         5  Someone has contacted our dating service and e...      Spam
# ..      ...                                                ...       ...
# 120     121  7 wonders in My WORLD 7th You 6th Ur style 5th...  Non-Spam
# 121     122  Try to do something dear. You read something f...  Non-Spam
# 122     123  Sun ah... Thk mayb can if dun have anythin on....  Non-Spam
# 123     124  SYMPTOMS when U are in love: "1.U like listeni...  Non-Spam
# 124     125  Great. Have a safe trip. Dont panic surrender ...  Non-Spam
#
#                                     Case Normalization  \
# 0    upgrdcentre orange customer, you may now claim...
# 1    loan for any purpose £500 - £75,000. homeowner...
# 2    congrats! nokia 3650 video camera phone is you...
# 3    urgent! your mobile number has been awarded wi...
# 4    someone has contacted our dating service and e...
# ..                                                 ...
# 120  7 wonders in my world 7th you 6th ur style 5th...
# 121  try to do something dear. you read something f...
# 122  sun ah... thk mayb can if dun have anythin on....
# 123  symptoms when u are in love: "1.u like listeni...
# 124  great. have a safe trip. dont panic surrender ...
#
#                                          Noise Removal  \
# 0    upgrdcentre orange customer you may now claim ...
# 1    loan for any purpose £ £ homeowners tenants we...
# 2    congrats nokia video camera phone is your call...
# 3    urgent your mobile number has been awarded wit...
# 4    someone has contacted our dating service and e...
# ..                                                 ...
# 120  wonders in my world th you th ur style th ur s...
# 121  try to do something dear you read something fo...
# 122  sun ah thk mayb can if dun have anythin on thk...
# 123  symptoms when u are in love u like listening s...
# 124    great have a safe trip dont panic surrender all
#
#                                           Tokenization  \
# 0    ['upgrdcentre', 'orange', 'customer', 'you', '...
# 1    ['loan', 'for', 'any', 'purpose', '£', '£', 'h...
# 2    ['congrats', 'nokia', 'video', 'camera', 'phon...
# 3    ['urgent', 'your', 'mobile', 'number', 'has', ...
# 4    ['someone', 'has', 'contacted', 'our', 'dating...
# ..                                                 ...
# 120  ['wonders', 'in', 'my', 'world', 'th', 'you', ...
# 121  ['try', 'to', 'do', 'something', 'dear', 'you'...
# 122  ['sun', 'ah', 'thk', 'mayb', 'can', 'if', 'dun...
# 123  ['symptoms', 'when', 'u', 'are', 'in', 'love',...
# 124  ['great', 'have', 'a', 'safe', 'trip', 'dont',...
#
#                                              Stopwords  \
# 0    ['upgrdcentre', 'orange', 'customer', 'may', '...
# 1    ['loan', 'purpose', '£', '£', 'homeowners', 't...
# 2    ['congrats', 'nokia', 'video', 'camera', 'phon...
# 3    ['urgent', 'mobile', 'number', 'awarded', '£',...
# 4    ['someone', 'contacted', 'dating', 'service', ...
# ..                                                 ...
# 120  ['wonders', 'world', 'th', 'th', 'ur', 'style'...
# 121  ['try', 'something', 'dear', 'read', 'somethin...
# 122  ['sun', 'ah', 'thk', 'mayb', 'dun', 'anythin',...
# 123  ['symptoms', 'u', 'love', 'u', 'like', 'listen...
# 124  ['great', 'safe', 'trip', 'dont', 'panic', 'su...
#
#                                               Stemming  \
# 0    ['upgrdcentr', 'orang', 'custom', 'you', 'may'...
# 1    ['loan', 'for', 'ani', 'purpos', '£', '£', 'ho...
# 2    ['congrat', 'nokia', 'video', 'camera', 'phone...
# 3    ['urgent', 'your', 'mobil', 'number', 'ha', 'b...
# 4    ['someon', 'ha', 'contact', 'our', 'date', 'se...
# ..                                                 ...
# 120  ['wonder', 'in', 'my', 'world', 'th', 'you', '...
# 121  ['tri', 'to', 'do', 'someth', 'dear', 'you', '...
# 122  ['sun', 'ah', 'thk', 'mayb', 'can', 'if', 'dun...
# 123  ['symptom', 'when', 'u', 'are', 'in', 'love', ...
# 124  ['great', 'have', 'a', 'safe', 'trip', 'dont',...
#
#                                          Lemmatization
# 0    ['upgrdcentre', 'orange', 'customer', 'you', '...
# 1    ['loan', 'for', 'any', 'purpose', '£', '£', 'h...
# 2    ['congrats', 'nokia', 'video', 'camera', 'phon...
# 3    ['urgent', 'your', 'mobile', 'number', 'ha', '...
# 4    ['someone', 'ha', 'contacted', 'our', 'dating'...
# ..                                                 ...
# 120  ['wonder', 'in', 'my', 'world', 'th', 'you', '...
# 121  ['try', 'to', 'do', 'something', 'dear', 'you'...
# 122  ['sun', 'ah', 'thk', 'mayb', 'can', 'if', 'dun...
# 123  ['symptom', 'when', 'u', 'are', 'in', 'love', ...
# 124  ['great', 'have', 'a', 'safe', 'trip', 'dont',...
#
# [125 rows x 9 columns]
